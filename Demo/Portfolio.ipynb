# %%
from XQuant import Portfolio

p = Portfolio(
        ticker=["000001", "000063", "000413", "002007"],
        begin="20160101",
        end="20180101",
    )

# %%
closes, returns = p.get_close_and_returns()

# %%
closes.head()
# Out:
# ticker      000001  000063  000413  002007
# 2016-01-04   11.33   16.92    8.17   40.39
# 2016-01-05   11.40   17.22    7.96   40.22
# 2016-01-06   11.53   17.38    8.13   40.95
# 2016-01-07   10.94   15.78    7.32   37.50
# 2016-01-08   11.12   16.23    7.49   38.53

# %%
returns.head()
# Out:
# ticker        000001    000063    000413    002007
# 2016-01-04       NaN       NaN       NaN       NaN
# 2016-01-05  0.006159  0.017575 -0.026040 -0.004218
# 2016-01-06  0.011339  0.009249  0.021132  0.017987
# 2016-01-07 -0.052527 -0.096577 -0.104951 -0.088011
# 2016-01-08  0.016319  0.028118  0.022958  0.027096

# %%
res = p.optimize_weights()

# %%
res["optv"]
# Out:
# OptimizeResult(weight=array([0.59542059, 0.14627141, 0.12956208, 0.12874592]), target=0.23087683760247232, message='Optimization terminated successfully', success=True, status=0, njev=7, nfev=35, nit=7, jac=array([0.23091189, 0.23080486, 0.23068237, 0.23099219]), name=['000001', '000063', '000413', '002007'])

# %%
res["optv"].portfolio
# Out:
# {'000001': 0.595420591988104,
#  '000063': 0.14627140895141078,
#  '000413': 0.12956208039006464,
#  '002007': 0.12874591867042057}

# %%
res["opts"]
# Out:
# OptimizeResult(weight=array([1.66533454e-16, 1.00000000e+00, 1.11022302e-16, 0.00000000e+00]), target=-1.110308750224449, message='Optimization terminated successfully', success=True, status=0, njev=2, nfev=10, nit=2, jac=array([9.66530144e-02, 1.49011612e-08, 2.58276939e-01, 9.60505038e-01]), name=['000001', '000063', '000413', '002007'])

# %%
res["opts"].portfolio
# Out:
# {'000001': 1.6653345369377348e-16,
#  '000063': 1.0,
#  '000413': 1.1102230246251565e-16,
#  '002007': 0.0}
